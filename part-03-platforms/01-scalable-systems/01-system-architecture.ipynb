# %% [markdown]
# # System Architecture
# ## Guiding Principles
# - Microservices over Monolith
# - Stream over Batch
# - Kappa over Lambda
# - Generic over Specific Cloud

# %% [markdown]
# ## Microservices over Monolith
#
# TBD

# %% [markdown]
# ## Stream over Batch
# TBD

# %% [markdown]
# ## Kappa over Lambda
#
# ### Kappa Architecture
# ![image.png](attachment:def061b0-0eed-4f10-a3ef-13670f42d39b.png)
#
# ### Lambda Architecture
# ![image.png](attachment:eb23e67a-2e23-4c56-8b9e-49e41769f082.png)

# %% [markdown]
# ## Generic over Specific Cloud
# Cloud providers
# - Amazon AWS
# - Google GCP
# - Microsoft Azur
