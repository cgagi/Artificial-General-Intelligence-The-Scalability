# %% [markdown]
# # System Design
# - Process types
# - Modules
# - OOP / API Design
# - Patterns
# - Blueprints

# %% [markdown]
# ## Process Types
# Different process types
# - Realtime
# - Streaming
# - Batch
#
# ![image.png](attachment:410c8e87-68d7-4a7a-9d5a-69b37ee21416.png)
