# %% [markdown]
# # Overview: Large Scale Distributed AI System

# %% [markdown]
# ![image.png](attachment:3dbc17d0-9751-4102-bb60-b03b0b70f95f.png)

# %% [markdown]
# # AI Data Platform

# %% [markdown]
# ![image.png](attachment:16ae7460-e70f-4f31-a9ce-5fb37e770d33.png)

# %% [markdown]
# # Featurestore and Knowledge Graph
# ### Important Concepts
# - Stream First
# - Datasets creation with Time Machine

# %% [markdown]
# ![image.png](attachment:634b895d-b773-4a65-8617-e2c99a59f2d7.png)

# %% [markdown]
# # Model Training & Serving
# ## Important Concepts
# - Tiered Inference
# - Synchronized vs Asynchronized Inference
# - Workflow & Automations
# - Online & Offline Labeling

# %% [markdown]
# ![image.png](attachment:0a5d8a3b-f555-49f6-b84b-b789ca3e8be1.png)
